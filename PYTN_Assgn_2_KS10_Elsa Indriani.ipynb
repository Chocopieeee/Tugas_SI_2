# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Mengambil dan menampilkan data

# %%
sal = pd.read_csv("nyc-rolling-sales.csv")
sal.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
sal.dtypes
# Out:
# Unnamed: 0                         int64
# BOROUGH                            int64
# NEIGHBORHOOD                      object
# BUILDING CLASS CATEGORY           object
# TAX CLASS AT PRESENT              object
# BLOCK                              int64
# LOT                                int64
# EASE-MENT                         object
# BUILDING CLASS AT PRESENT         object
# ADDRESS                           object
# APARTMENT NUMBER                  object
# ZIP CODE                           int64
# RESIDENTIAL UNITS                  int64
# COMMERCIAL UNITS                   int64
# TOTAL UNITS                        int64
# LAND SQUARE FEET                  object
# GROSS SQUARE FEET                 object
# YEAR BUILT                         int64
# TAX CLASS AT TIME OF SALE          int64
# BUILDING CLASS AT TIME OF SALE    object
# SALE PRICE                        object
# SALE DATE                         object
# dtype: object

# %%
thn = sal['YEAR BUILT'] 
thn
# Out:
# 0        1900
# 1        1900
# 2        1900
# 3        1913
# 4        1900
#          ...
# 84543    1998
# 84544    1998
# 84545    1925
# 84546    2001
# 84547    2006
# Name: YEAR BUILT, Length: 84548, dtype: int64

# %%
sal.tail()
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84543        8409        5      WOODROW
# 84544        8410        5      WOODROW
# 84545        8411        5      WOODROW
# 84546        8412        5      WOODROW
# 84547        8413        5      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 84543   7349   34                                  B9          37 QUAIL LANE
# 84544   7349   78                                  B9       32 PHEASANT LANE
# ...

# %%
df = sal[['TOTAL UNITS','SALE PRICE']]
df
# Out:
#        TOTAL UNITS SALE PRICE
# 0                5    6625000
# 1               31        -
# 2               17        -
# 3               10    3936272
# 4                6    8000000
# ...            ...        ...
# 84543            2     450000
# 84544            2     550000
# 84545            2     460000
# 84546            7   11693337
# 84547            1      69300
#
# [84548 rows x 2 columns]

# %% [markdown]
# ### Merubah isi kolom borough menjadi nama wilayahnya

# %%
satu = sal[['BOROUGH','TOTAL UNITS','SALE PRICE']].dropna()
satu.BOROUGH = sal.BOROUGH.map({1:'Manhattan', 2:'Bronx', 3:'Brooklyn', 4:'Queens', 5:'Staten Island'})
satu
# Out:
#              BOROUGH  TOTAL UNITS SALE PRICE
# 0          Manhattan            5    6625000
# 1          Manhattan           31        -
# 2          Manhattan           17        -
# 3          Manhattan           10    3936272
# 4          Manhattan            6    8000000
# ...              ...          ...        ...
# 84543  Staten Island            2     450000
# 84544  Staten Island            2     550000
# 84545  Staten Island            2     460000
# 84546  Staten Island            7   11693337
# 84547  Staten Island            1      69300
#
# [84548 rows x 3 columns]

# %%
satu.dtypes
# Out:
# BOROUGH        object
# TOTAL UNITS     int64
# SALE PRICE     object
# dtype: object

# %% [markdown]
# ### Jumlah dari total units

# %%
satu['TOTAL UNITS'].sum()
# Out:
# 190164

# %% [markdown]
# ### Mean data borough manhattan

# %%
dua = satu.iloc[:18306,:]
dua
# Out:
#          BOROUGH  TOTAL UNITS SALE PRICE
# 0      Manhattan            5    6625000
# 1      Manhattan           31        -
# 2      Manhattan           17        -
# 3      Manhattan           10    3936272
# 4      Manhattan            6    8000000
# ...          ...          ...        ...
# 18301  Manhattan            1        -
# 18302  Manhattan            0    7500000
# 18303  Manhattan            1        -
# 18304  Manhattan            1        -
# 18305  Manhattan            1        -
#
# [18306 rows x 3 columns]

# %%
m1 = 190164/18305
m1
# Out:
# 10.388636984430484

# %% [markdown]
# ### Mencari Median dari data manhattan yaitu data 9152 dan 9153

# %%
tiga = satu.iloc[:9155,:]
tiga
# Out:
#         BOROUGH  TOTAL UNITS SALE PRICE
# 0     Manhattan            5    6625000
# 1     Manhattan           31        -
# 2     Manhattan           17        -
# 3     Manhattan           10    3936272
# 4     Manhattan            6    8000000
# ...         ...          ...        ...
# 9150  Manhattan            1    1850000
# 9151  Manhattan            1    3800000
# 9152  Manhattan            1   16550062
# 9153  Manhattan            1   23500000
# 9154  Manhattan            1   22500000
#
# [9155 rows x 3 columns]

# %%
nilte = (1+1)/2
nilte
# Out:
# 1.0

# %%
from collections import Counter
import statistics as stat


data = dua[['TOTAL UNITS']]
dat = len(data)

data2 = Counter(data)
get_mod = dict(data)
get_mod
# Out:
# {'TOTAL UNITS': 0         5
#  1        31
#  2        17
#  3        10
#  4         6
#           ..
#  18301     1
#  18302     0
#  18303     1
#  18304     1
#  18305     1
#  Name: TOTAL UNITS, Length: 18306, dtype: int64}

# %% [markdown]
# ### Varians

# %%
n = 18305
mean_ = 190164/18305
var_ = mean_/n
var_
# Out:
# 0.0005675300182698981

# %% [markdown]
# ### Standar Deviasi

# %%
std_ = var_ ** 0.5
std_
# Out:
# 0.023822888537494737
